# %%
from pylab import *
from scipy.integrate import *
from numpy import *
# %matplotlib inline
import random

# %%
def ec_mov(x_p,t,a=0):
    #x_p representa x, y,px, py; r32 representa r^(3/2)
    r32 = (x_p[0]**2 + x_p[1]**2)**(1.5)
    desv = 1. + a
    dx = x_p[2]*desv
    dy = x_p[3]
    dpx = -(x_p[0]*desv)/r32
    dpy = -(x_p[1]*desv)/r32
    return array([dx,dy,dpx,dpy])

# %%
def r_k4(ec,p_ini,x,args=0,h=0.01):
    if (x[1]-x[0]) <= 5.*h:
        h = (x[1]-x[0])/10
    tiempos = arange(x[0],x[1]+h,h)
    sol = zeros((len(tiempos),len(p_ini)))
    sol[0,:] = p_ini
    if args==0:
        for i in xrange(len(tiempos)-1):
            k1 = ec(sol[i,:],tiempos[i])
            k2 = ec(sol[i,:]+0.5*h*k1,tiempos[i]+0.5*h)
            k3 = ec(sol[i,:]+0.5*h*k2,tiempos[i]+0.5*h)
            k4 = ec(sol[i,:]+h*k3,tiempos[i]+h)
            sol[i+1,:]=sol[i,:]+(h/6.)*(k1+2*k2+2*k3+k4)
    else:
        for i in xrange(len(tiempos)-1):
            k1 = ec(sol[i,:],tiempos[i],args)
            k2 = ec(sol[i,:]+0.5*h*k1,tiempos[i]+0.5*h,args)
            k3 = ec(sol[i,:]+0.5*h*k2,tiempos[i]+0.5*h,args)
            k4 = ec(sol[i,:]+h*k3,tiempos[i]+h,args)
            sol[i+1,:]=sol[i,:]+(h/6.)*(k1+2*k2+2*k3+k4)
    return tiempos,sol

# %%
#alpha=0.5
alpha=0.01

t,sol = r_k4(ec_mov,[1,0,0,0.5],[0,30],.05,0.01)
#########################################
t1=linspace(0,30)#10)#,1000)
t2=linspace(0,30,10)#,1000)
t3=linspace(0,30,1000)#,1000)
#Estamos jugano con este tiempo
t4=linspace(0,2*pi*50,5000)#,1000 2*pi*años
####################################
sol1 = odeint(ec_mov,[1,0,0,0.5],t1,args=(0.05,))
sol2 = odeint(ec_mov,[1,0,0,0.5],t2,args=(0.05,))
sol3 = odeint(ec_mov,[1,0,0,0.5],t3,args=(0.05,))
#Estamos jugando con esta
sol4 = odeint(ec_mov,[1,0,0,1],t4,args=(alpha,),rtol=1e-15)
sol4_2 = odeint(ec_mov,[.99,sqrt(1-.99**2),0,1],t4,args=(alpha,),rtol=1e-15)
#args=variable juega con el puedes quitarlo
####################################
print "Odeint t4"
plot(sol4[:,0],sol4[:,1], label="Linspace0-30,10000")
plot(sol4_2[:,0],sol4_2[:,1], label="Linspace0-30,10000")
plot(sol4[-1,0],sol4[-1,1],"o",label="condicion ini")
plot(sol4[0,0],sol4[0,1],"o",label="condicion ini")
plot(sol4_2[-1,0],sol4_2[-1,1],"x",label="condicion ini")
plot(sol4_2[0,0],sol4_2[0,1],"x",label="condicion ini")
grid(True)
legend()
show()
####################################
print "Runge-Kutta"
grid(True)
plot(sol[:,0],sol[:,1],label="Runge-Kutta")
legend()
show()
#################################
# ylim([-1.5,1.5])
# xlim([-0.2,1])
####################################
grid(True)
print "Odeint t1-t3"
plot(sol1[:,0],sol1[:,1], label="Linspace0-30")
plot(sol2[:,0],sol2[:,1], label="Linspace0-30,10")
plot(sol3[:,0],sol3[:,1], label="Linspace0-30,100")
legend()
show()
# Out:
# Odeint t4
# Runge-Kutta
# Odeint t1-t3

# %%
def Energia(x_p,a):
    x,y,px,py = x_p[:,0],x_p[:,1],x_p[:,2],x_p[:,3]
    E = 0.5*(px*px *(1.+a)+py*py)-((1. +a)/sqrt(x**2 + y**2))
    return E

def L_z(x_p):
    x,y,px,py = x_p[:,0],x_p[:,1],x_p[:,2],x_p[:,3]
    L = x*py - y*px
    return L

# %%
E = Energia(sol4,alpha)
E_2 = Energia(sol4_2,alpha)
ylim([E[0]-.00001,E[0]+.00001])
a=t4/(2*pi)
b=E
c=E_2
plot(a,b, label="Grafica de la energia")
plot(a,c, label="Grafica de la energia")
# xticks(arange(0,1,0.1))
# yticks(arange(E[0]-.0000001,E[0]+.0000001,0.1)
legend()
#scatter(a, b)
grid(True)#,alpha=0.002)
show()

# %%
L=L_z(sol4)
L_2=L_z(sol4_2)
ylim([L[0]-.1,L[0]+.1])
plot(t4/(2*pi),L,label="Grafica del momento angular")
plot(t4/(2*pi),L_2,label="Grafica del momento angular nuevo mov")
legend()
grid(True)
show()

# %%
xlim([0,10])
ylim([-.57,-.43])
# plot(t4/(2*pi),sol4[:,0])
# plot(t4/(2*pi),50*(L-1))
# plot(t4/(2*pi),50*(L_2-1))
plot(t4/(2*pi),50*((L_2-L)),label="Grafica del momento angular nuevo mov")
legend()
